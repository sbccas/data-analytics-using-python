# %% [markdown]
# # 🧭 Teaching Plan (Theory Sessions)

# %% [markdown]
# | Week  | Lecture | Key Topics                                                                     | Teaching Method                                   | Tools/Examples                              |
# | ----- | ------- | ------------------------------------------------------------------------------ | ------------------------------------------------- | ------------------------------------------- |
# | **1** | **L1**  | *Introduction to Data Analytics & EDA*  — definition, scope, need for EDA      | Concept explanation + discussion on real datasets | PPT + whiteboard                            |
# |       | **L2**  | *Types of EDA* — Univariate, Bivariate, Multivariate analysis with examples    | Visual examples from students.csv                 | Colab demo                                  |
# | **2** | **L3**  | *Understanding the Data* — Quantitative vs Qualitative (data types + examples) | Interactive classification activity               | Pandas `info()`, `dtypes`                   |
# |       | **L4**  | *Handling Missing Data and Outliers* — techniques (mean/median/mode, IQR)      | Stepwise Colab walk-through                       | Pandas `fillna()`, `dropna()`; boxplots     |
# | **3** | **L5**  | *Data Distribution & Spread* — Normal vs Skewed distributions + visuals        | Diagrammatic illustration + code demo             | Matplotlib, Seaborn                         |
# |       | **L6**  | *Measuring Skewness & Kurtosis* + Mini Case Study discussion                   | Guided analysis on StudentsPerformance.csv        | `df.skew()`, `df.kurt()` outputs discussion |

# %% [markdown]
# # 🧪 Lab Plan (Practical Sessions)

# %% [markdown]
# | Week  | Lab No.   | Focus Area                              | Activities                                                        | Deliverable                                   |
# | ----- | --------- | --------------------------------------- | ----------------------------------------------------------------- | --------------------------------------------- |
# | **1** | **Lab 1** | Intro to Colab & Data Import            | Create a new Colab notebook; import Pandas/Numpy; load sample CSV | Saved notebook `Lab1_EDA_Intro.ipynb`         |
# |       | **Lab 2** | Univariate Analysis                     | Use histograms and value counts for categorical columns           | Notebook with two charts                      |
# | **2** | **Lab 3** | Bivariate Analysis & Correlation        | Scatter plots and `df.corr()` matrix                              | Screenshot of plots + Markdown interpretation |
# |       | **Lab 4** | Handling Missing Data                   | Identify nulls and impute with mean/median                        | Notebook with before/after tables             |
# | **3** | **Lab 5** | Detecting & Handling Outliers           | Boxplot + IQR method filtering                                    | Cleaned dataset CSV                           |
# |       | **Lab 6** | Distribution Analysis (Skew & Kurtosis) | Compute and interpret metrics + histograms                        | Markdown summary with plots                   |

# %% [markdown]
# ## 🧰 Tools & Resources
#
# * Python 3.10+
# * Google Colab
# * Pandas, NumPy, Matplotlib, Seaborn
#
# * Datasets: StudentsPerformance.csv, iris.csv, house_prices.csv
