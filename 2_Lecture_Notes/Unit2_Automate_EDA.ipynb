# %% [markdown]
# ### Unit-2 Automate EDA (Exploratory Data Analysis)
# ##### 2.1 Python Libraries to Automate Exploratory Data Analysis
#          2.1.1 Pandas and Numpy
# ##### 2.2 Regression
#          2.2.1 Characteristics of Regression
#          2.2.2 Dependent and Independent variables
#          2.2.3 Covariance and Correlation
# ##### 2.3 Machine Learning Basics:
#          2.3.1 Concepts of Machine learning
#          2.3.1.1 Understanding machine learning
#          2.3.1.2 Benefit of machine learning
#          2.3.1.2 Machine learning life cycle
# ##### 2.4 Types of Machine Learning:
#          2.4.1 Supervised and Unsupervised Learning
#          2.4.2 Applications of ML in real-world scenarios

# %% [markdown]
# ## 🔹 2.1 Python Libraries to Automate Exploratory Data Analysis (EDA)
#
# ### **Introduction**
#
# Exploratory Data Analysis (EDA) is the first and most important step in any data analysis or data science project.
# It helps us understand the **structure, patterns, trends, and anomalies** present in a dataset before applying any machine learning or statistical model.
#
# Python provides powerful libraries that **automate and simplify EDA tasks**, such as:
#
# * Loading datasets
# * Cleaning data
# * Handling missing values
# * Computing statistical summaries
# * Understanding distributions and relationships
#
# The two most fundamental libraries for automated EDA are **NumPy** and **Pandas**.
#
# ---
#
# ### **Why Python for EDA?**
#
# Python is widely used for EDA because:
#
# * It is easy to learn and readable
# * It supports large datasets
# * It has rich libraries for data handling and visualization
# * It integrates well with machine learning frameworks
#
# ---
#
# ## 🔹 2.1.1 Pandas and NumPy
#
# ---
#
# ## 🅰 NumPy (Numerical Python)
#
# ### **Definition**
#
# NumPy is a core Python library for numerical and mathematical operations.
# It provides support for **multi-dimensional arrays** and **high-performance numerical computations**.
#
# ---
#
# ### **Role of NumPy in EDA**
#
# NumPy is mainly used for:
#
# * Numerical computations
# * Mathematical and statistical operations
# * Working with arrays and matrices
# * Supporting Pandas internally for fast calculations
#
# ---
#
# ### **Key Features of NumPy**
#
# * N-dimensional array object (`ndarray`)
# * Fast execution using optimized C code
# * Mathematical functions (mean, median, standard deviation, etc.)
# * Linear algebra and random number generation
#
# ---
#
# ### **Common NumPy Operations in EDA**
#
# * Finding mean, median, variance
# * Normalization of data
# * Handling numerical missing values
# * Generating sample data
#
# ---
#
# ### **Example: NumPy in EDA**
#
# ```python
# import numpy as np
#
# data = np.array([10, 20, 30, 40, 50])
#
# print("Mean:", np.mean(data))
# print("Standard Deviation:", np.std(data))
# ```
#
# ---
#
# ### **Advantages of NumPy**
#
# * Very fast for numerical calculations
# * Efficient memory usage
# * Foundation for scientific computing in Python
#
# ### **Limitations of NumPy**
#
# * Does not handle labeled or tabular data directly
# * No built-in support for data cleaning or CSV files
#
# ---
#
# ## 🅱 Pandas (Python Data Analysis Library)
#
# ### **Definition**
#
# Pandas is a high-level data analysis library built on top of NumPy.
# It is specifically designed to work with **structured (tabular) data**, similar to Excel sheets or database tables.
#
# ---
#
# ### **Role of Pandas in Automated EDA**
#
# Pandas automates most EDA tasks such as:
#
# * Loading data from files (CSV, Excel, SQL)
# * Viewing and summarizing data
# * Handling missing values
# * Filtering and transforming data
# * Generating descriptive statistics
#
# ---
#
# ### **Core Data Structures in Pandas**
#
# 1. **Series** – One-dimensional labeled data
# 2. **DataFrame** – Two-dimensional table with rows and columns
#
# ---
#
# ### **Common Pandas Functions Used in EDA**
#
# ```markdown
# | Function            | Purpose                                  |
# |---------------------|------------------------------------------|
# | `read_csv()`        | Load dataset                             |
# | `head()` / `tail()` | View sample records                     |
# | `shape`             | Dataset size                             |
# | `info()`            | Data types and null values               |
# | `describe()`        | Statistical summary                      |
# | `isnull()`          | Detect missing values                    |
# | `fillna()`          | Handle missing values                    |
# | `value_counts()`    | Frequency distribution                  |
# ```
#
# ---
#
# ### **Example: Pandas for EDA**
#
# ```python
# import pandas as pd
#
# df = pd.read_csv("data.csv")
#
# print(df.head())
# print(df.info())
# print(df.describe())
# ```
#
# ---
#
# ### **How Pandas Automates EDA**
#
# * Automatically computes count, mean, min, max, and quartiles
# * Quickly identifies missing values
# * Supports filtering, sorting, and grouping
# * Works seamlessly with visualization libraries
#
# ---
#
# ### **Advantages of Pandas**
#
# * Easy to learn and use
# * Handles large datasets efficiently
# * Ideal for real-world data analysis
# * Strong integration with NumPy, Matplotlib, and Seaborn
#
# ### **Limitation**
#
# * Slightly slower for very large numerical computations compared to pure NumPy
#
# ---
#
# ### **Relationship Between NumPy and Pandas**
#
# * Pandas is built on top of NumPy
# * NumPy handles numerical efficiency
# * Pandas provides data structures and automation
# * Together they form the foundation of Python-based EDA
#
# ---
#
# ### **Summary**
#
# * NumPy → Numerical and mathematical operations
# * Pandas → Tabular data analysis and automated EDA
# * Both libraries are essential for understanding data before applying machine learning
# * They significantly reduce manual effort and improve analysis accuracy
#
# ### **Exam-Oriented Key Points**
#
# * NumPy → Numerical computation
# * Pandas → Tabular data analysis
# * describe() → Automated statistics
# * info() → Structure and missing values
# * Pandas + NumPy → Core of EDA in Python

# %% [markdown]
# ---
#
# ## 🔹 2.2 Regression
#
# ### **Meaning of Regression**
#
# Regression is a statistical and analytical technique used to study the **relationship between variables** and to **predict the value of one variable based on another**.
#
# It answers questions such as:
#
# * How does one variable change when another changes?
# * Can we predict future outcomes based on past data?
#
# **Example:**
# Predicting student marks based on hours of study.
#
# ---
#
# ### **2.2.1 Characteristics of Regression**
#
# 1. **Relationship Analysis**
#
#    * Measures cause–effect relationship
#    * One variable influences another
#
#    📌 Example: Rainfall → Crop yield
#
# 2. **Direction of Relationship**
#
#    * Positive: Both variables increase together
#    * Negative: One increases, the other decreases
#
#    📌 Example:
#
#    * More study hours → Higher marks (positive)
#    * Higher price → Lower demand (negative)
#
# 3. **Predictive Nature**
#
#    * Used for prediction and forecasting
#    * Helps in decision-making
#
#    📌 Example: Predicting sales for the next month.
#
# 4. **Mathematical Model**
#
#    * Regression creates a mathematical equation that represents the relationship.
#
# Simple Linear Regression Equation:
#
#    ```text
#    y = a + bx
#    ```
#
#    where
#
#    * `y` = dependent variable
#    * `x` = independent variable
#    * `a` = intercept
#    * `b` = slope
#
# 5. **One-way Dependency**
#
#    * Independent variable affects dependent variable
#    * Unlike correlation, the dependency is not mutual.
#
#
# ---
#
# ### **2.2.2 Dependent and Independent Variables**
#
# #### **Independent Variable (X)**
#
# * Causes change
# * Also called predictor or explanatory variable
#
# Examples:
#
# * Hours studied
# * Temperature
# * Advertising budget
#
# #### **Dependent Variable (Y)**
#
# * The variable that depends on X
# * Also called response or target variable
#
# Examples:
#
# * Exam score
# * Ice-cream sales
# * Product demand
#
# ---
#
# ### **Simple Example Table**
#
# ```markdown
# | Independent Variable (X) | Dependent Variable (Y) |
# |--------------------------|------------------------|
# | Hours of study           | Marks obtained         |
# | Rainfall                 | Crop yield             |
# | Experience (years)       | Salary                 |
# ```
#
#
# 📌 Key Point:
# X influences Y, but Y does not influence X
#
# ---
#
# ## 🔹 2.2.3 Covariance and Correlation
#
# ### **A. Covariance**
#
# Covariance measures how two variables change together.
#
# **Interpretation**
#
# * Positive → move in same direction
# * Negative → move in opposite direction
# * Zero → no linear relationship
#
# 📌 Example:
# * Study hours & marks → Positive covariance
# * Price & demand → Negative covariance
#
# **Limitation**
#
# * Covariance does not show strength of relationship
# * Depends on the units of measurement
#
# ---
#
# ### **B. Correlation**
#
# Correlation measures **direction and strength** of relationship.
#
# 📌 Correlation value ranges from –1 to +
#
# | Value | Interpretation               |
# | ----- | ---------------------------- |
# | +1    | Perfect positive correlation |
# | –1    | Perfect negative correlation |
# | 0     | No correlation               |
#
#
# 📌 Example:
# * Height & weight → Strong positive correlation
# * Speed & travel time → Negative correlation
# ---
#
# ### **Difference Between Covariance and Correlation**
#
# ```markdown
# | Feature            | Covariance | Correlation |
# |--------------------|------------|-------------|
# | Measures direction | ✔️         | ✔️          |
# | Measures strength  | ❌         | ✔️          |
# | Unit dependent     | ✔️         | ❌          |
# | Range              | –∞ to +∞   | –1 to +1    |
# ```
#
# #### Relation to Regression
# * Correlation tells how strongly variables are related.
# * Regression tells how much Y changes when X changes.
#
# 📌 Correlation explains association, regression explains prediction.
#
# Summary:
# * Regression predicts outcomes.
# * Independent variable causes change.
# * Dependent variable responds to change.
# * Covariance shows direction.
# * Correlation shows direction and strength.
#
# ---
#
#
# ### **Python Example: Regression**
#
# Step 1: Import Libraries
#
# ```python
# import numpy as np
# import pandas as pd
# ```
# Step 2: Create Dataset
# ```python
# data = {
#     'Hours_Studied': [1, 2, 3, 4, 5, 6],
#     'Marks': [35, 40, 50, 55, 65, 70]
# }
#
# df = pd.DataFrame(data)
# df
# ```
# Out put of df
# 📌 Explanation:
# • Hours_Studied → Independent Variable (X)
# • Marks → Dependent Variable (Y)
#
# Step 3: Separate Independent and Dependent
# Variables
# ```python
# X = df['Hours_Studied']
# Y = df['Marks']
# ```
# Step 4: Calculate Regression Line (Using NumPy)
# ```python
# # Calculate slope (b) and intercept (a)
# b, a = np.polyfit(X, Y, 1)
# print("Slope (b):", b)
# print("Intercept (a):", a)
# ```
# output:
# ![image.png](attachment:image.png)
#
# 📌 Regression Equation:
# Marks = a + b * Hours_Studied
#
# Step 5: Predict Marks for New Data
#
# ```python
# # Prediction
# hours = 7
# predicted_marks = a + b * hours
# predicted_marks
# ```
# Output:
# ![image-2.png](attachment:image-2.png)
#
#
# 📌 Interpretation:
# “If a student studies for 7 hours, the model
# predicts the marks.”
#
# ---
#
# #### Python Examples using Pandas & NumPy for Covariance and Correlation
#
# ##### 🔹 Introduction
#
# In data analytics, understanding the **relationship between variables** is essential.
# Two important statistical measures used for this purpose are:
#
# * **Covariance**
# * **Correlation**
#
# These measures help identify how variables move together and how strong their relationship is.
#
# ---
#
# ## 🔹 A. Covariance
#
# ### **Meaning of Covariance**
#
# Covariance tells us **how two variables change together**.
#
# It shows:
#
# * Whether two variables **increase or decrease together**, or
# * Whether **one increases while the other decreases**.
#
# ---
#
# ### **Interpretation of Covariance**
#
# * **Positive Covariance** 👉 Both variables move in the same direction
#   *(When X increases, Y also increases)*
#
# * **Negative Covariance** 👉 Variables move in opposite directions
#   *(When X increases, Y decreases)*
#
# * **Zero Covariance** 👉 No clear linear relationship
#
# ---
#
# ### **Examples of Covariance**
#
# * **Hours Studied and Marks Scored**
#
#   * More study → More marks
#   * Covariance is **positive**
#
# * **Speed of a Vehicle and Time Taken**
#
#   * More speed → Less time
#   * Covariance is **negative**
#
# ---
#
# ### **Important Points about Covariance**
#
# * Covariance shows **direction**, not strength
# * Value depends on **units of measurement**
# * Used in:
#
#   * Statistics
#   * Data analysis
#   * Finance
#   * Machine learning
#
# ---
#
# ### **Relation between Covariance and Correlation**
#
# ```markdown
# | Covariance              | Correlation                     |
# |-------------------------|---------------------------------|
# | Shows direction         | Shows direction + strength      |
# | Unbounded value         | Value between –1 and +1         |
# | Unit dependent          | Unit free                       |
# ```
#
# ---
#
# ### **Definition**
#
# > **Covariance is a statistical measure that indicates the direction of the linear relationship between two variables.**
#
# ---
#
# ### **Computing Covariance using Pandas**
#
# ```python
# covariance = df['Hours_Studied'].cov(df['Marks'])
# covariance
# ```
# ![image-3.png](attachment:image-3.png)
#
# ### **Computing Covariance using NumPy**
#
# ```python
# import numpy as np
#
# cov_matrix = np.cov(X, Y)
# cov_matrix
# ```
#
# ---
#
# ### **Explanation of Covariance Matrix**
#
# * **Diagonal values** → Variance
# * **Off-diagonal values** → Covariance
# * **Positive value** → Variables move in same direction
#
# ---
#
# ## 🔹 B. Correlation
#
# ### **Meaning of Correlation**
#
# Correlation measures **both the direction and strength** of the relationship between two variables.
#
# ---
#
# ### **Computing Correlation using Pandas**
#
# ```python
# correlation = df['Hours_Studied'].corr(df['Marks'])
# correlation
# ```
# ![image-4.png](attachment:image-4.png)
#
# ---
#
# ### **Computing Correlation using NumPy**
#
# ```python
# corr_matrix = np.corrcoef(X, Y)
# corr_matrix
# ```
#
# ---
#
# ### **Interpretation of Correlation Values**
#
# * Value close to **+1** → Strong positive correlation
# * Value close to **–1** → Strong negative correlation
# * Value close to **0** → Weak or no correlation
#
# ---
#
# ## 🔹 Combined Example with Multiple Variables
#
# ### **Create Dataset**
#
# ```python
# import pandas as pd
#
# data2 = {
#     'Study_Hours': [2, 3, 4, 5, 6],
#     'Sleep_Hours': [8, 7, 6, 6, 5],
#     'Marks': [40, 45, 55, 60, 68]
# }
#
# df2 = pd.DataFrame(data2)
# df2
# ```
#
# ---
#
# ### **Covariance Matrix**
#
# ```python
# df2.cov()
# ```
# ![image-5.png](attachment:image-5.png)
#
#
# ### **Correlation Matrix**
#
# ```python
# df2.corr()
# ```
# ![image-6.png](attachment:image-6.png)
#
#
# ## 🔹 Summary
#
# * **Regression** → Prediction
# * **Covariance** → Direction of relationship
# * **Correlation** → Direction + Strength
# * **Pandas** → Easy and readable implementation
# * **NumPy** → Mathematical foundation
#
# ---

# %% [markdown]
# ## 🔹 2.3 Machine Learning Basics
#
# ### **Definition**
#
# Machine Learning (ML) is a subset of Artificial Intelligence (AI) that enables computers to **learn from data**, identify patterns, and make **decisions or predictions without being explicitly programmed**.
#
#
# ###### **Simple Meaning for Students**
#
# > **“Instead of writing rules, we give data to the machine and it learns the rules by itself.”**
#
#
# ## 🔹 Traditional Programming vs Machine Learning
#
# ```markdown
# | Traditional Programming        | Machine Learning               |
# |--------------------------------|--------------------------------|
# | Data + Rules → Output          | Data + Output → Rules          |
# | Fixed logic                    | Learns automatically           |
# | Needs manual updates           | Improves with experience       |
# ```
#
# ### **Example**
#
# * **Traditional Programming:**
#   Writing if-else rules to detect spam emails
#
# * **Machine Learning:**
#   Training a model using thousands of spam and non-spam emails
#
# ---
#
# ## 🔹 How Machine Learning Works
#
# 1. Data is collected
# 2. Data is given to an ML algorithm
# 3. Algorithm learns patterns
# 4. A model is created
# 5. Model makes predictions on new data
#
# ---
#
# ## 🔹 Real-World Examples of Machine Learning
#
# * Netflix movie recommendations
# * Google search results
# * Face recognition on smartphones
# * Credit card fraud detection
#
# ---
#
# ## 🔹 Types of Machine Learning (Introductory)
#
# 1. **Supervised Learning**
#
#    * Data with labels
#
# 2. **Unsupervised Learning**
#
#    * Data without labels
#
# 3. **Reinforcement Learning**
#
#    * Learning using rewards and penalties
#
# ---
#
# ## 🔹 2.3.1.2 Benefits of Machine Learning
#
# ![image.png](attachment:image.png)
#
# Machine Learning provides several advantages over traditional systems:
#
# ### **1. Automation**
#
# * Reduces manual work
# * Automates repetitive tasks
#
# 📌 *Example:* Auto-sorting emails into spam and inbox
#
# ---
#
# ### **2. Accuracy and Efficiency**
#
# * Handles large datasets efficiently
# * Improves accuracy over time
#
# 📌 *Example:* Medical diagnosis systems
#
# ---
#
# ### **3. Pattern Recognition**
#
# * Detects hidden patterns humans may miss
#
# 📌 *Example:* Customer behavior analysis in e-commerce
#
# ---
#
# ### **4. Scalability**
#
# * Works well with big data
# * Can process millions of records quickly
#
# 📌 *Example:* Recommendation engines
#
# ---
#
# ### **5. Continuous Learning**
#
# * Models improve with new data
#
# 📌 *Example:* Voice assistants understanding accents better over time
#
# ---
#
# ### **6. Better Decision Making**
#
# * Data-driven decisions
# * Reduces human bias
#
# 📌 *Example:* Loan approval systems
#
# ---
#
# > 📌 **Machine Learning systems are adaptive, scalable, and intelligent.**
#
# ---
#
# ## 🔹 2.3.1.3 Machine Learning Life Cycle
#
# The **Machine Learning Life Cycle** defines the step-by-step process followed to build, train, and deploy an ML model.
#
# ![image-2.png](attachment:image-2.png)
#
# ---
#
# ### **Steps in the Machine Learning Life Cycle**
#
# ---
#
# ### **Step 1: Problem Definition**
#
# * Clearly define the problem
# * Decide:
#
#   * What to predict?
#   * Type of ML (Classification / Regression)
#
# 📌 *Example:* Predict student performance
#
# ---
#
# ### **Step 2: Data Collection**
#
# * Collect data from:
#
#   * Databases
#   * Sensors
#   * Surveys
#   * Open datasets (Kaggle, UCI)
#
# 📌 **Quality data is more important than quantity**
#
# ---
#
# ### **Step 3: Data Preprocessing**
#
# * Handle missing values
# * Remove noise
# * Normalize or scale data
# * Convert categorical data
#
# 📌 *This is the most time-consuming step*
#
# ---
#
# ### **Step 4: Exploratory Data Analysis (EDA)**
#
# * Understand data distribution
# * Identify patterns and outliers
# * Use charts and statistics
#
# 📌 *Example:* Mean, median, correlation
#
# ---
#
# ### **Step 5: Feature Selection & Engineering**
#
# * Select important features
# * Create new features if required
#
# 📌 *Good features → Better model*
#
# ---
#
# ### **Step 6: Model Selection**
#
# Choose appropriate algorithm such as:
#
# * Linear Regression
# * Decision Tree
# * KNN
# * SVM
#
# ---
#
# ### **Step 7: Model Training**
#
# * Split data into:
#
#   * Training set
#   * Testing set
# * Train model using training data
#
# ---
#
# ### **Step 8: Model Evaluation**
#
# Check performance using:
#
# * Accuracy
# * Precision
# * Recall
# * RMSE
#
# 📌 *Ensures model reliability*
#
# ---
#
# ### **Step 9: Model Deployment**
#
# * Deploy model into real-world application
# * Integrate with software or system
#
# 📌 *Example:* Web or mobile application
#
# ---
#
# ### **Step 10: Monitoring & Maintenance**
#
# * Monitor performance
# * Retrain model with new data
#
# 📌 *Machine Learning is a continuous process*
#
# ---
#
# ## 🔹 Machine Learning Flow
#
# ```text
# Problem → Data → Preprocessing → EDA → Feature Selection →
# Model Training → Evaluation → Deployment → Monitoring
# ```
#
# ---
#
# ## 🔹 Summary
#
# * Machine Learning enables systems to learn from data
# * It improves automation and accuracy
# * ML life cycle follows systematic steps
# * Good data and features are critical.
# * Forms the foundation of modern intelligent systems
#
# ---

# %% [markdown]
# # 📘 **Unit 2.4 – Types of Machine Learning**
#
# ## 🔹 Introduction to Types of Machine Learning
#
# Machine Learning (ML) is a subfield of **Artificial Intelligence (AI)** that focuses on building algorithms and models that allow computers to:
#
# * Learn from data
# * Improve with experience
# * Make decisions without explicit programming for every task
#
# ### **In simple words**
#
# > *Machine Learning teaches systems to learn patterns and make decisions like humans by analyzing data.*
#
# There are **three main types of Machine Learning**:
#
# 1. Supervised Machine Learning
# 2. Unsupervised Machine Learning
# 3. Reinforcement Learning
#
# ![image.png](attachment:image.png)
#
# ---
#
# ## 🔹 1. Supervised Machine Learning
#
# ### **Definition**
#
# Supervised Learning is defined as a learning method where a model is trained on a **labeled dataset**.
#
# * Labeled data contains **input variables (features)** and **output variables (labels)**
# * The algorithm learns a mapping between input and correct output
# * Both training and validation datasets are labeled
#
# ---
#
# ### **Key Characteristics of Supervised Learning**
#
# * Requires labeled data
# * Learns from known outcomes
# * Used for prediction tasks
# * Suitable for both classification and regression problems
#
# ![image-2.png](attachment:image-2.png)
#
# ### **Two Main Categories of Supervised Learning**
#
# ---
#
# ## **1. Classification**
#
# ### **Meaning**
#
# Classification predicts **categorical outputs**, meaning it assigns data points to predefined classes.
#
# ### **Examples**
#
# * Spam vs Non-spam emails
# * Disease present / not present
# * Pass / Fail classification
#
# ---
#
# ### **Common Classification Algorithms**
#
# * Logistic Regression
# * Decision Tree
# * Random Forest
# * K-Nearest Neighbors (KNN)
# * Naive Bayes
# * Support Vector Machine (SVM)
#
# ---
#
# ## **2. Regression**
#
# ### **Meaning**
#
# Regression predicts **continuous numerical values**.
#
# ### **Examples**
#
# * House price prediction
# * Sales forecasting
# * Salary prediction
#
# ---
#
# ### **Common Regression Algorithms**
#
# * Linear Regression
# * Polynomial Regression
# * Ridge Regression
# * Lasso Regression
# * Decision Tree
# * Random Forest
#
# ---
#
# ### **Where to Use Supervised Learning**
#
# * When labeled historical data is available
# * When predicting outcomes is required
# * Suitable for:
#
#   * Classification problems
#   * Regression problems
#
# ---
#
# ### **Applications of Supervised Learning**
#
# * Image, speech, and text processing
#
# For tasks like image classification, speech recognition and sentiment analysis.
#
# * Predictive analytics (sales, churn, stock prices)
#
# To forecast sales, customer churn, stock prices and weather conditions.
#
# * Recommendation and personalization systems
#
# Powering systems that suggest products, movies or content.
#
# * Healthcare (diagnosis)
# * Finance (fraud detection, credit scoring)
#
# Used for medical diagnosis, fraud detection and credit scoring.
#
# * Automation and control systems
#
# In autonomous vehicles,manufacturing quality checks and gaming AI.
#
# ---
#
# ## 🔹 2. Unsupervised Machine Learning
#
# ### **Definition**
#
# Unsupervised Learning works with **unlabeled data**, meaning there are no predefined outputs.
#
# * The algorithm identifies **hidden patterns or structures**
# * No training labels are provided
# * Useful for exploratory data analysis
#
# ---
#
# ### **Key Characteristics**
#
# * No labeled output
# * Finds patterns automatically
# * Used mainly for:
#
#   * Clustering
#   * Dimensionality reduction
#   * Data visualization
#
#
# ![image-3.png](attachment:image-3.png)
#
# ### **Example**
#
# In case of customer data without labels, the algorithm can group similar customers based on purchase behavior useful for segmentation and marketing
#
# ---
#
# ## 🔹 Categories of Unsupervised Learning
#
# ---
#
# ### **1. Clustering**
#
# Clustering is the process of grouping data points into clusters based on their similarity. This technique is useful for identifying patterns and relationships in data without the need for labeled examples.
#
# ### **Common Clustering Algorithms**
#
# * K-Means
# * DBSCAN
# * Mean-Shift
#
# ---
#
# ### **2. Dimensionality Reduction**
#
# Reduces the number of features while preserving important information.
#
# ### **Common Techniques**
#
# * Principal Component Analysis (PCA)
# * Independent Component Analysis (ICA)
#
# ---
#
# ### **3. Association Rule Learning**
#
# Finds relationships between items in large datasets. It identifies rules that indicate the presence of one item implies the presence of another item with a specific probability.
#
# ### **Common Techniques**
#
# * Apriori
# * FP-Growth
# * Eclat
#
# ---
#
# ### **Uses of Unsupervised Learning**
#
# * When data is unlabeled or unstructured
# * Useful for exploratory analysis, clustering or feature extraction.
# * Common in marketing, recommendation systems and fraud detection where patterns matter more than labels.
# * Feature extraction
#
# ---
#
# ### **Applications of Unsupervised Learning**
#
# * Clustering and segmentation
#
# Group similar data points, customers or images.
#
# * Anomaly and fraud detection
#
# Spot unusual patterns or outliers in data.
#
# * Dimensionality reduction:
#
# Simplify large datasets while retaining key information.
#
# * Marketing analytics
# * Customer behavior analysis
#
# Identify user preferences and improve product suggestions.
#
# * Data preprocessing and analysis
#
# Clean data, detect patterns and support exploratory data analysis (EDA).
#
#
# ---
#
# ## 🔹 3. Reinforcement Learning (Overview)
#
# Reinforcement Learning is based on **reward and penalty**.
#
# * The agent learns by interacting with an environment
# * Actions are rewarded or penalized
# * Goal is to maximize total reward
#
# ### **Examples**
#
# * Game playing AI
# * Robotics
# * Autonomous vehicles
#
# ---
#
# ## 🔹 Summary Table
#
# ```markdown
# | Type of ML        | Data Type     | Main Purpose                    |
# |-------------------|---------------|---------------------------------|
# | Supervised        | Labeled       | Prediction & classification     |
# | Unsupervised      | Unlabeled     | Pattern discovery & clustering  |
# | Reinforcement     | Reward-based  | Decision making                 |
# ```
#
# ---

# %% [markdown]
# ##### 📘 **Unit 2.4 – Applications of Machine Learning in Real-World Scenarios**
#
# ###### 🔹 Introduction
#
# Machine learning (ML) is changing how we approach problems, make decisions and interact with the world around us.
# By analyzing data and recognizing patterns, it enables smarter decisions, improves processes and helps solve complex challenges.
#
# As machine learning continues to evolve, its impact keeps growing, transforming industries and enhancing the way we live and work.
#
# ---
#
# ## 🔹 Role of Machine Learning in Data Preprocessing and Analysis
#
#
# ![image.png](attachment:image.png)
#
# Machine learning supports **data preprocessing and analysis** by performing tasks such as:
#
# * Cleaning data
# * Detecting patterns
# * Supporting exploratory data analysis (EDA)
#
# These steps help prepare data for accurate analysis and effective decision-making.
#
# ---
#
# ## 🔹 1. Machine Learning in Healthcare
#
# Machine learning is transforming healthcare by helping professionals:
#
# * Diagnose conditions more accurately
# * Personalize treatments
# * Manage patient data efficiently
#
# With AI-powered systems, machine learning mimics human decision-making, improving medical practices and reducing risks.
#
# ![image-2.png](attachment:image-2.png)
#
# ### **Real-Life Examples of Machine Learning in Healthcare**
#
# #### **1. Disease Diagnosis and Risk Prediction**
#
# Machine learning analyzes patient data such as medical records and test results to predict disease risks.
# Early detection helps doctors take preventive actions, improving long-term health outcomes.
#
# ---
#
# #### **2. Medical Imaging Analysis**
#
# Machine learning enhances the interpretation of medical images like X-rays and MRIs.
# It identifies patterns and issues that may be missed by the human eye, enabling earlier diagnosis and more effective treatments.
#
# ---
#
# #### **3. Drug Discovery**
#
# Machine learning accelerates the analysis of large datasets to identify potential drugs.
# This speeds up the development of new medications and treatment methods.
#
# ---
#
# #### **4. Virtual Assistants and Chatbots**
#
# AI-powered chatbots assist with tasks such as:
#
# * Answering patient queries
# * Scheduling appointments
# * Providing basic health advice
#
# This reduces the workload on healthcare staff and improves operational efficiency.
#
# ---
#
# ## 🔹 2. Machine Learning in Finance
#
# Machine learning is revolutionizing the finance industry by transforming how financial data is analyzed and how decisions are made.
# By processing huge amounts of data, it helps financial institutions:
#
# * Make informed decisions
# * Detect fraud
# * Improve customer services
# * Predict financial trends
#
# ![image-3.png](attachment:image-3.png)
#
# ### **Real-Life Examples of Machine Learning in Finance**
#
# #### **1. Fraud Detection**
#
# Machine learning analyzes transaction patterns to identify anomalies in real-time.
# This helps detect fraudulent activity before it leads to major financial losses.
#
# ---
#
# #### **2. Loan Approval and Credit Scoring**
#
# ML models evaluate an individual’s financial history, credit score and related data to predict repayment ability.
# This improves loan approval processes and reduces the risk of bad lending.
#
# ---
#
# #### **3. Algorithmic Trading**
#
# Financial institutions use machine learning algorithms to analyze market trends and execute trades at high speeds.
# This enables more accurate and timely investment decisions.
#
# ---
#
# #### **4. Robo-Advisors**
#
# AI-driven platforms use machine learning to create personalized investment portfolios based on user risk tolerance and financial goals.
# This improves investment strategies and makes financial planning more accessible.
#
# ---
#
# ## 🔹 3. Machine Learning in Marketing and Advertising
#
# Machine learning is transforming marketing and advertising by:
#
# * Automating repetitive tasks
# * Personalizing customer experiences
# * Improving decision-making
#
# It helps businesses run efficient digital advertising campaigns, optimize content and create customized recommendations.
#
# With machine learning, marketers save time and resources and can focus more on strategy and creativity.
#
# ![image-4.png](attachment:image-4.png)
#
# ### **Real-Life Examples of Machine Learning in Marketing and Advertising**
#
# #### **1. Targeted Advertising**
#
# Machine learning analyzes user data such as browsing history and demographics to deliver personalized advertisements.
# This ensures ads reach the right audience, increasing engagement and conversion rates.
#
# ---
#
# #### **2. Content Recommendation**
#
# Platforms like Netflix and Spotify use machine learning to recommend content based on user preferences.
# This personalized approach keeps users engaged for longer periods.
#
# ---
#
# #### **3. Dynamic Pricing**
#
# E-commerce platforms use machine learning to adjust product prices in real-time.
# By analyzing demand, competition and market factors, businesses can maximize profit while remaining competitive.
#
# ---
#
# #### **4. Chatbots and Virtual Assistants**
#
# AI-powered chatbots assist customers by:
#
# * Answering inquiries
# * Providing product information
# * Placing orders
#
# This enables faster, 24×7 customer service and improves user satisfaction.
#
# ---
#
# ## 🔹 4. Machine Learning in Autonomous Vehicles
#
# Machine learning plays a vital role in the development of autonomous vehicles, allowing them to operate without human intervention.
#
# Using sensors such as:
#
# * Cameras
# * Radar
# * LiDAR
#
# Autonomous vehicles analyze their environment, make decisions and adapt to different driving conditions.
#
# ![image-5.png](attachment:image-5.png)
#
#
# ### **Examples of Machine Learning in Autonomous Vehicles**
#
# #### **1. Perception of Surroundings**
#
# Machine learning helps vehicles “see” their environment by processing sensor data.
# This enables detection of vehicles, pedestrians and traffic signals in real-time.
#
# ---
#
# #### **2. Object Detection and Classification**
#
# Algorithms use large image databases to distinguish between objects such as pedestrians and stationary items.
# This ensures accurate recognition and safe navigation.
#
# ---
#
# #### **3. Navigation and Path Planning**
#
# After perceiving the environment, machine learning helps plan optimal routes considering traffic signals, road signs and shortest paths.
#
# ---
#
# #### **4. Adapting to Different Conditions**
#
# Machine learning enables self-driving cars to adapt to weather conditions such as rain, snow and fog, as well as different road types.
# This ensures safe and efficient vehicle operation under all conditions.
#
# ---
#
# ## 🔹 5. Machine Learning in Retail
#
# Machine learning is changing the retail industry by helping businesses:
#
# * Understand customer needs
# * Optimize inventory management
# * Personalize shopping experiences
#
# By analyzing customer data, sales patterns and market trends, retailers can forecast demand, adjust pricing strategies and improve customer interactions.
#
# ![image-6.png](attachment:image-6.png)
#
#
# ### **Examples of Machine Learning in Retail**
#
# #### **1. Demand Forecasting**
#
# Machine learning analyzes sales data, consumer behavior and external factors like weather to predict future demand.
# This helps retailers avoid overstocking and stockouts.
#
# ---
#
# #### **2. Dynamic Pricing**
#
# Prices are adjusted in real-time based on demand and competition.
# This helps retailers optimize profit margins and increase sales of slow-moving products.
#
# ---
#
# #### **3. Customer Segmentation and Targeting**
#
# Machine learning analyzes purchasing patterns to create customer segments.
# This allows targeted marketing campaigns and higher conversion rates.
#
# ---
#
# #### **4. Optimizing In-Store Layout**
#
# Customer movement data is analyzed to strategically place high-demand products, improving accessibility and driving sales.
#
# ---
#
# ## 🔹 6. Machine Learning in Education
#
# Machine learning is revolutionizing education by:
#
# * Personalizing learning experiences
# * Automating administrative tasks
# * Predicting student performance
#
# By analyzing data such as attendance, performance and learning behavior, institutions can improve learning outcomes.
#
# ![image-7.png](attachment:image-7.png)
#
# ### **Examples of Machine Learning in Education**
#
# #### **1. Personalized Learning**
#
# Platforms like Coursera and Duolingo recommend lessons based on student progress, learning style and weak areas.
#
# ---
#
# #### **2. Early Dropout Prediction**
#
# Universities use machine learning to analyze attendance, grades and engagement to identify students at risk and provide timely support.
#
# ---
#
# #### **3. Automated Grading**
#
# AI-powered systems evaluate multiple-choice tests and even essays, reducing teacher workload.
#
# ---
#
# #### **4. Virtual Tutors**
#
# ML-based chatbots act as tutors, answering student queries and providing explanations outside classroom hours.
#
# ---
#
# #### **5. Adaptive Assessments**
#
# Online learning platforms use ML to adjust question difficulty based on the learner’s performance in real-time.
#
# ---
