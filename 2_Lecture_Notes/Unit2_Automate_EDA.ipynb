# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\Hitesh\AppData\Local\Programs\Python\Python313\python.exe
# 3.13.9 (tags/v3.13.9:8183fa5, Oct 14 2025, 14:09:13) [MSC v.1944 64 bit (AMD64)]
